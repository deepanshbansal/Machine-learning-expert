# %% [markdown]
# ## LOAD THE DATA

# %%
import pandas as pd
housing=pd.read_excel('data.xlsx',names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'],header=None)
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## MISSING THE ATTRIBUTES
#     1. Get rid of the missing data points.
#     2. Get rid of the data if you have large number of dataset.
#     3. Set the value to mean,mode and median.

# %%
housing.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ## PLOTING TH PLOT OF EACH FEATURES

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
housing.hist(bins=50,figsize=(20,10))
plt.show()

# %%
import seaborn as sns
sns.pairplot(housing)

# %% [markdown]
# ## TRAIN TEST SPLITTING

# %%
#import numpy as np
#def split_train_test(data,test_ratio):
#    np.random.seed(42)
#    shuffled=np.random.permutation(len(data))
#    test_set_size=int(len(data) * test_ratio)
#    test_indices=shuffled[:test_set_size]
#    train_indices=shuffled[test_set_size:]
#    return data.iloc[train_indices],data.iloc[test_indices]

# %%
#ratio=0.20
#train_set,test_set=split_train_test(housing,ratio)
#print(len(train_set))
#print(len(test_set))

# %%
#print(f'Rows in train set: {(len(train_set))}\nRows in test set: {(len(test_set))}\n')

# %%
#from sklearn.model_selection import train_test_split
#train_set,test_set=train_test_split(housing,test_size=0.2,random_state=0)
#print(f'Rows in train set: {(len(train_set))}\nRows n test set: {(len(test_set))}\n')

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(housing,housing['CHAS']):
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_train_set.describe()
#len(strat_test_set)
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279908
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712983
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %% [markdown]
# ## LOOKING FOR CORRELATIONS

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
#From above correaltions we can know that if we increase RM then MEDV will increase and if we decrease LSTAT then RM wil increase
#simultaneously if we increase LSTAT then RM will decrease.

# %%
from pandas.plotting import scatter_matrix
attributes=['MEDV','RM','ZN','LSTAT']
scatter_matrix(housing[attributes],figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A02381A1D0>,
# ...
#       dtype=object)

# %%
import seaborn as sns
sns.pairplot(housing)

# %%
housing.plot(kind='scatter',x='RM',y='MEDV')

# %%
housing.plot(kind='scatter',x='LSTAT',y='MEDV')

# %%
housing.plot(kind='scatter',x='MEDV',y='ZN')

# %% [markdown]
# #

# %%
housing.plot(kind='scatter',x='RM',y='MEDV')

# %% [markdown]
# ## Standardise the data using Standard Scaler

# %%
train_data=strat_train_set.iloc[:,0:13]
train_label=strat_train_set.iloc[:,13]
test_data=strat_test_set.iloc[:,0:13]
test_label=strat_test_set.iloc[:,13]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_train_data=sc.fit_transform(train_data)
scaled_train_data
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %% [markdown]
# ## creating model for predictions

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model=LinearRegression()
#model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(scaled_train_data,train_label)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
testing_data=sc.fit_transform(test_data)

# %%
pred=model.predict(testing_data)
pred
# Out:
# array([23.85,  9.92, 25.44, 21.94, 17.36, 14.39, 19.63, 15.79, 33.94,
#        43.11, 20.5 ,  8.89, 25.7 , 25.13, 20.06, 13.13, 34.64, 16.99,
#        24.  , 16.76, 19.13, 16.48, 19.92, 21.5 , 17.8 , 31.23, 16.08,
#        33.29,  9.31, 34.92, 24.46, 21.6 , 23.99,  9.3 , 20.85, 13.15,
#        42.47, 24.87, 23.3 , 44.18, 23.46, 28.06, 20.8 , 21.58, 16.34,
#        32.  , 44.84, 21.37, 19.08, 21.68, 22.63, 15.86, 20.2 , 14.23,
#        24.79, 35.5 , 47.11, 26.96, 17.85, 20.88, 47.29, 10.67, 19.34,
#        23.21, 14.17, 40.56, 19.81, 16.81, 16.48, 35.28, 24.9 , 23.12,
#        20.12, 22.54, 36.5 , 13.53, 14.84, 19.44, 21.66, 21.53, 22.1 ,
#        22.12, 15.43, 24.32, 21.2 , 21.49, 14.62, 19.81, 22.26, 23.49,
#        17.32, 25.74,  7.73, 26.58, 17.27, 32.39, 21.51, 33.28, 13.28,
#        25.43, 18.33, 18.68])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
lin_mse=mean_squared_error(pred,test_label)
lin_rmse=np.sqrt(lin_mse)
print(lin_mse)
# Out:
# 12.874303921568625

# %%
lin_rmse
# Out:
# 3.588078026126052

# %% [markdown]
# ## Using better evaluation technique  Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,train_data,train_label,scoring='neg_mean_squared_error',cv=10)
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([2.65532645, 3.06050689, 4.50464638, 2.68830167, 3.70574723,
#        3.21197758, 5.02601482, 3.41994846, 4.23643364, 2.82431894])

# %%
def print_scores(scores):
    print('Scores :',scores)
    print('Mean :',scores.mean())
    print('Standard Deviation:',scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores : [2.65532645 3.06050689 4.50464638 2.68830167 3.70574723 3.21197758
#  5.02601482 3.41994846 4.23643364 2.82431894]
# Mean : 3.5333222070804644
# Standard Deviation: 0.7760792590437434

# %%
from joblib import dump, load
dump(model,'REAL_ESTATE.joblib')
# Out:
# ['REAL_ESTATE.joblib']
